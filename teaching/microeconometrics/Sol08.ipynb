# %% [markdown]
# ## Solutions

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ### Exercise 1

# %%
from linearmodels.iv import IV2SLS

data=pd.read_stata('data/mus06data.dta')
data=data.dropna(subset=['linc'])
formula = 'ldrugexp ~ 1 + totchr + female + age + linc + blhisp + [hi_empunion ~ multlc+firmsz]'
res = IV2SLS.from_formula(formula, data).fit(cov_type='robust')
print(res.first_stage)
print('\n'.join(res.summary.as_text().split('\n')[8:]))
# Out:
#     First Stage Estimation Results
# ======================================
#                            hi_empunion
# --------------------------------------
# R-squared                       0.0646
# Partial R-squared               0.0058
# Shea's R-squared                0.0058
# Partial F-statistic             58.687
# P-value (Partial F-stat)     1.804e-13
# Partial F-stat Distn           chi2(2)
# ========================== ===========
# Intercept                       0.9010
#                               (15.276)
# totchr                          0.0109
#                               (2.9662)
# female                         -0.0794
#                              (-8.2030)
# age                            -0.0092
#                              (-12.926)
# linc                            0.0722
#                               (11.607)
# blhisp                         -0.0743
#                              (-6.0078)
# multlc                          0.1419
#                               (6.8044)
# firmsz                          0.0040
#                               (2.1246)
# --------------------------------------
#
# T-stats reported in parentheses
# T-stats use same covariance type as original model
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# Intercept       7.3672     0.4482     16.438     0.0000      6.4888      8.2457
# totchr          0.4565     0.0119     38.369     0.0000      0.4331      0.4798
# female         -0.0694     0.0458    -1.5152     0.1297     -0.1592      0.0204
# age            -0.0193     0.0048    -3.9836     0.0001     -0.0288     -0.0098
# linc            0.1349     0.0378     3.5730     0.0004      0.0609      0.2089
# blhisp         -0.2588     0.0501    -5.1711     0.0000     -0.3569     -0.1607
# hi_empunion    -1.5061     0.4285    -3.5150     0.0004     -2.3459     -0.6663
# ===============================================================================
#
# Endogenous: hi_empunion
# Instruments: multlc, firmsz
# Robust Covariance (Heteroskedastic)
# Debiased: False

# %%
from linearmodels.iv.results import compare

res_ols = IV2SLS.from_formula('ldrugexp ~ 1 + hi_empunion + totchr + female + age + linc + blhisp', data).fit(cov_type='robust')
compare([res,res_ols])
# Out:
#                 Model Comparison
# ================================================
#                            Model 0       Model 1
# ------------------------------------------------
# Dep. Variable             ldrugexp      ldrugexp
# Estimator                  IV-2SLS           OLS
# No. Observations             10089         10089
# Cov. Est.                   robust        robust
# R-squared                  -0.1220        0.1770
# Adj. R-squared             -0.1226        0.1765
# F-statistic                 1643.9        2262.6
# P-value (F-stat)            0.0000        0.0000
# ==================     ===========   ===========
# Intercept                   7.3672        5.8611
#                           (16.438)      (37.320)
# totchr                      0.4565        0.4404
#                           (38.369)      (47.049)
# female                     -0.0694        0.0578
#                          (-1.5152)      (2.2797)
# age                        -0.0193       -0.0035
#                          (-3.9836)     (-1.8228)
# linc                        0.1349        0.0105
#                           (3.5730)      (0.7646)
# blhisp                     -0.2588       -0.1513
#                          (-5.1711)     (-4.4353)
# hi_empunion                -1.5061        0.0739
#                          (-3.5150)      (2.8441)
# ==================== ============= =============
# Instruments                 multlc
#                             firmsz
# ------------------------------------------------
#
# T-stats reported in parentheses
# IVModelComparison, id: 0x21fa47e4548

# %%
res.wu_hausman()
# Out:
# Wu-Hausman test of exogeneity
# H0: All endogenous variables are exogenous
# Statistic: 21.3325
# P-value: 0.0000
# Distributed: F(1,10081)
# WaldTestStatistic, id: 0x21fa4751c48

# %%
res.sargan
# Out:
# Sargan's test of overidentification
# H0: The model is not overidentified.
# Statistic: 2.6073
# P-value: 0.1064
# Distributed: chi2(1)
# WaldTestStatistic, id: 0x21fa45f2548

# %%
from linearmodels.iv import IVGMM

res_gmm = IVGMM.from_formula(formula, data).fit(cov_type='robust')
print(res_gmm.first_stage)
print('\n'.join(res_gmm.summary.as_text().split('\n')[8:]))
# Out:
#     First Stage Estimation Results
# ======================================
#                            hi_empunion
# --------------------------------------
# R-squared                       0.0646
# Partial R-squared               0.0058
# Shea's R-squared                0.0058
# Partial F-statistic             58.687
# P-value (Partial F-stat)     1.804e-13
# Partial F-stat Distn           chi2(2)
# ========================== ===========
# Intercept                       0.9010
#                               (15.276)
# totchr                          0.0109
#                               (2.9662)
# female                         -0.0794
#                              (-8.2030)
# age                            -0.0092
#                              (-12.926)
# linc                            0.0722
#                               (11.607)
# blhisp                         -0.0743
#                              (-6.0078)
# multlc                          0.1419
#                               (6.8044)
# firmsz                          0.0040
#                               (2.1246)
# --------------------------------------
#
# T-stats reported in parentheses
# T-stats use same covariance type as original model
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# Intercept       7.3269     0.4442     16.495     0.0000      6.4563      8.1975
# totchr          0.4561     0.0118     38.624     0.0000      0.4330      0.4793
# female         -0.0651     0.0454    -1.4356     0.1511     -0.1541      0.0238
# age            -0.0189     0.0048    -3.9309     0.0001     -0.0283     -0.0095
# linc            0.1315     0.0374     3.5153     0.0004      0.0582      0.2048
# blhisp         -0.2543     0.0496    -5.1241     0.0000     -0.3515     -0.1570
# hi_empunion    -1.4653     0.4245    -3.4516     0.0006     -2.2973     -0.6332
# ===============================================================================
#
# Endogenous: hi_empunion
# Instruments: multlc, firmsz
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)

# %%
res_gmm.c_stat()
# Out:
# C-statistic
# H0: All endogenous variables are exogenous
# Statistic: 16.8790
# P-value: 0.0000
# Distributed: chi2(1)
# WaldTestStatistic, id: 0x21fa44ed188

# %%
res_gmm.j_stat
# Out:
# H0: Expected moment conditions are equal to 0
# Statistic: 2.0259
# P-value: 0.1546
# Distributed: chi2(1)
# WaldTestStatistic, id: 0x21fcc5fd988

# %% [markdown]
# ### Exercise 2

# %%
from linearmodels.iv import IVLIML
res_liml = IVLIML.from_formula(formula, data).fit(cov_type='robust')
compare([res,res_liml,res_gmm])
# Out:
#                        Model Comparison
# ==============================================================
#                            Model 0       Model 1       Model 2
# --------------------------------------------------------------
# Dep. Variable             ldrugexp      ldrugexp      ldrugexp
# Estimator                  IV-2SLS       IV-LIML        IV-GMM
# No. Observations             10089         10089         10089
# Cov. Est.                   robust        robust        robust
# R-squared                  -0.1220       -0.1503       -0.1067
# Adj. R-squared             -0.1226       -0.1510       -0.1074
# F-statistic                 1643.9        1601.9        1667.5
# P-value (F-stat)            0.0000        0.0000        0.0000
# ==================     ===========   ===========   ===========
# Intercept                   7.3672        7.4369        7.3269
#                           (16.438)      (15.779)      (16.495)
# totchr                      0.4565        0.4572        0.4561
#                           (38.369)      (37.687)      (38.624)
# female                     -0.0694       -0.0753       -0.0651
#                          (-1.5152)     (-1.5808)     (-1.4356)
# age                        -0.0193       -0.0200       -0.0189
#                          (-3.9836)     (-3.9399)     (-3.9309)
# linc                        0.1349        0.1407        0.1315
#                           (3.5730)      (3.5440)      (3.5153)
# blhisp                     -0.2588       -0.2638       -0.2543
#                          (-5.1711)     (-5.1226)     (-5.1241)
# hi_empunion                -1.5061       -1.5792       -1.4653
#                          (-3.5150)     (-3.4795)     (-3.4516)
# ==================== ============= ============= =============
# Instruments                 multlc        multlc        multlc
#                             firmsz        firmsz        firmsz
# --------------------------------------------------------------
#
# T-stats reported in parentheses
# IVModelComparison, id: 0x21f9cf48388

# %% [markdown]
# ### Exercise 3

# %%
res1 = IV2SLS.from_formula('ldrugexp ~ 1 + totchr + female + age + linc + blhisp + [hi_empunion ~ ssiratio]', data).fit(cov_type='robust')
res2 = IV2SLS.from_formula('ldrugexp ~ 1 + totchr + female + age + linc + blhisp + [hi_empunion ~ ssiratio+lowincome]', data).fit(cov_type='robust')
res3 = IV2SLS.from_formula('ldrugexp ~ 1 + totchr + female + age + linc + blhisp + [hi_empunion ~ ssiratio+lowincome+multlc]', data).fit(cov_type='robust')
res4 = IV2SLS.from_formula('ldrugexp ~ 1 + totchr + female + age + linc + blhisp + [hi_empunion ~ ssiratio+lowincome+multlc+firmsz]', data).fit(cov_type='robust')
compare([res1,res2,res3,res4])
# Out:
#                               Model Comparison
# ============================================================================
#                            Model 0       Model 1       Model 2       Model 3
# ----------------------------------------------------------------------------
# Dep. Variable             ldrugexp      ldrugexp      ldrugexp      ldrugexp
# Estimator                  IV-2SLS       IV-2SLS       IV-2SLS       IV-2SLS
# No. Observations             10089         10089         10089         10089
# Cov. Est.                   robust        robust        robust        robust
# R-squared                   0.0640        0.1030        0.0809        0.0720
# Adj. R-squared              0.0634        0.1025        0.0804        0.0715
# F-statistic                 2000.9        2084.7        2036.3        2017.7
# P-value (F-stat)            0.0000        0.0000        0.0000        0.0000
# ==================     ===========   ===========   ===========   ===========
# Intercept                   6.7872        6.6101        6.7148        6.7536
#                           (25.246)      (26.366)      (27.625)      (27.611)
# totchr                      0.4503        0.4484        0.4495        0.4499
#                           (44.157)      (45.096)      (44.673)      (44.482)
# female                     -0.0204       -0.0055       -0.0143       -0.0176
#                          (-0.6257)     (-0.1761)     (-0.4646)     (-0.5672)
# age                        -0.0132       -0.0114       -0.0125       -0.0129
#                          (-4.4092)     (-4.0346)     (-4.5290)     (-4.6471)
# linc                        0.0870        0.0724        0.0810        0.0842
#                           (3.8436)      (3.4684)      (3.9703)      (4.0895)
# blhisp                     -0.2174       -0.2048       -0.2123       -0.2150
#                          (-5.5052)     (-5.3681)     (-5.5310)     (-5.5679)
# hi_empunion                -0.8976       -0.7119       -0.8217       -0.8623
#                          (-4.0592)     (-3.6027)     (-4.4320)     (-4.6153)
# ==================== ============= ============= ============= =============
# Instruments               ssiratio      ssiratio      ssiratio      ssiratio
#                                        lowincome     lowincome     lowincome
#                                                         multlc        multlc
#                                                                       firmsz
# ----------------------------------------------------------------------------
#
# T-stats reported in parentheses
# IVModelComparison, id: 0x21f9e6925c8

# %% [markdown]
# ### Exercise 4

# %%
res.first_stage.diagnostics
# Out:
#              rsquared  partial.rsquared  shea.rsquared     f.stat  \
# hi_empunion  0.064626          0.005774       0.005774  58.686708
#
#                    f.pval   f.dist
# hi_empunion  1.804112e-13  chi2(2)

# %% [markdown]
# ### Exercise 5

# %%
from linearmodels import IV3SLS

ldrugexp='ldrugexp ~ 1 + hi_empunion + totchr + age + female + linc + blhisp'
hi_empunion='hi_empunion ~ 1 + ldrugexp + totchr + female + blhisp + ssiratio'
equations = dict(ldrugexp=ldrugexp, hi_empunion=hi_empunion)
res_3sls = IV3SLS.from_formula(equations, data).fit(cov_type='robust')
print('\n'.join(res_3sls.summary.as_text().split('\n')[8:20]))
print('\n'.join(res.summary.as_text().split('\n')[8:]))
# Out:
#
#                 Equation: ldrugexp, Dependent Variable: ldrugexp
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# Intercept       5.8251     0.1270     45.873     0.0000      5.5762      6.0740
# hi_empunion     0.1532     0.0210     7.2982     0.0000      0.1120      0.1943
# totchr          0.4399     0.0076     58.069     0.0000      0.4251      0.4548
# age            -0.0034     0.0016    -2.1638     0.0305     -0.0065     -0.0003
# female          0.0652     0.0205     3.1758     0.0015      0.0250      0.1054
# linc            0.0071     0.0110     0.6474     0.5173     -0.0145      0.0288
# blhisp         -0.1457     0.0276    -5.2791     0.0000     -0.1998     -0.0916
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# Intercept       7.3672     0.4482     16.438     0.0000      6.4888      8.2457
# totchr          0.4565     0.0119     38.369     0.0000      0.4331      0.4798
# female         -0.0694     0.0458    -1.5152     0.1297     -0.1592      0.0204
# age            -0.0193     0.0048    -3.9836     0.0001     -0.0288     -0.0098
# linc            0.1349     0.0378     3.5730     0.0004      0.0609      0.2089
# blhisp         -0.2588     0.0501    -5.1711     0.0000     -0.3569     -0.1607
# hi_empunion    -1.5061     0.4285    -3.5150     0.0004     -2.3459     -0.6663
# ===============================================================================
#
# Endogenous: hi_empunion
# Instruments: multlc, firmsz
# Robust Covariance (Heteroskedastic)
# Debiased: False

# %% [markdown]
# ### Exercise 6

# %%
labels = pd.read_stata('data/mus06klingdata.dta', iterator=True)
labels.variable_labels()
# Out:
# {'black': 'Race (r0002300)',
#  'grade76': "'76 Grade level",
#  'smsa66': '= lived in SMSA in 1966',
#  'smsa76': '= lived in SMSA in 1976',
#  'col4': 'If any 4-year college nearby',
#  'mcol4': 'If male 4-year college nearby',
#  'col4pub': 'If public 4-year college nearby',
#  'south76': 'If lived in South in 1976',
#  'wage76': "'76 Wage",
#  'exp76': "'76 experience (10+age66)-grade76-6",
#  'expsq76': "'76 experience = exp76 ^2/100",
#  'age76': "'76 age (age66 +10)",
#  'agesq76': "'76 age squared (age76^2)",
#  'reg1': 'region==NE',
#  'reg2': '= lived in Region 2 MidAtl',
#  'reg3': '= lived in Region 3 ENC',
#  'reg4': '= lived in Region 4 WNC',
#  'reg5': '= lived in Region 5 SA',
#  'reg6': '= lived in Region 6 ESC',
#  'reg7': '= lived in Region 7 WSC',
#  'reg8': '= lived in Region 8 M',
#  'reg9': '= lived in Region 9 P',
#  'momdad14': '= lived with both parents at age 14',
#  'sinmom14': '= lived with mother only at age 14',
#  'nodaded': '= father has no formal education',
#  'nomomed': '= mother has no formal education',
#  'daded': 'Mean grade level of father',
#  'momed': 'Mean grade level of mother',
#  'famed1': '= mgrade>12 & fgrade>12',
#  'famed2': '= mgrade>=12 & fgrade>=12',
#  'famed3': '= mgrade==12 & fgrade==12',
#  'famed4': '= mgrade>=12 & fgrade==-1',
#  'famed5': '= fgrade>=12',
#  'famed6': '= mgrade>=12 & fgrade>-1',
#  'famed7': '= mgrade>=9 & fgrade>=9',
#  'famed8': '= mgrade>-1 & fgrade>-1',
#  'famed9': '= not in famed1-famed8'}

# %%
data=pd.read_stata('data/mus06klingdata.dta')
formula='wage76 ~ 1 + black+south76+smsa76+reg2+reg3+reg4+reg5+reg6+reg7+reg8+reg9+smsa66+sinmom14+nodaded+nomomed+daded+momed+famed1+famed2+famed3+famed4+famed5+famed6+famed7+famed8 + [grade76+exp76+expsq76 ~ col4+age76+agesq76]'
res = IV2SLS.from_formula(formula, data).fit(cov_type='robust')
print(res.first_stage)
print('\n'.join(res.summary.as_text().split('\n')[8:]))
# Out:
#                 First Stage Estimation Results
# ==============================================================
#                                grade76       exp76     expsq76
# --------------------------------------------------------------
# R-squared                       0.2953      0.7056      0.6754
# Partial R-squared               0.0081      0.6411      0.6094
# Shea's R-squared                0.0062      0.0860      0.0823
# Partial F-statistic             26.010      5318.9      3562.5
# P-value (Partial F-stat)      9.49e-06      0.0000      0.0000
# Partial F-stat Distn           chi2(3)     chi2(3)     chi2(3)
# ========================== =========== =========== ===========
# Intercept                      -4.0120     -1.9880      6.6009
#                              (-1.0468)   (-0.5187)    (7.7352)
# black                          -0.4444      0.4444      0.0810
#                              (-3.5571)    (3.5571)    (2.7505)
# south76                        -0.1231      0.1231      0.0456
#                              (-0.7702)    (0.7702)    (1.4659)
# smsa76                          0.7460     -0.7460     -0.1559
#                               (5.7931)   (-5.7931)   (-5.6309)
# reg2                            0.4128     -0.4128     -0.0658
#                               (1.9495)   (-1.9495)   (-1.4997)
# reg3                            0.4456     -0.4456     -0.0792
#                               (2.1576)   (-2.1576)   (-1.8388)
# reg4                            0.6262     -0.6262     -0.1254
#                               (2.6913)   (-2.6913)   (-2.5767)
# reg5                            0.2073     -0.2073     -0.0404
#                               (0.8259)   (-0.8259)   (-0.7729)
# reg6                            0.2095     -0.2095     -0.0202
#                               (0.7498)   (-0.7498)   (-0.3337)
# reg7                            0.4723     -0.4723     -0.1037
#                               (1.7265)   (-1.7265)   (-1.8308)
# reg8                            0.7338     -0.7338     -0.1577
#                               (2.4580)   (-2.4580)   (-2.5652)
# reg9                            0.6299     -0.6299     -0.1370
#                               (2.8100)   (-2.8100)   (-2.9528)
# smsa66                         -0.3521      0.3521      0.0658
#                              (-2.7799)    (2.7799)    (2.4653)
# sinmom14                       -0.1474      0.1474      0.0083
#                              (-0.7583)    (0.7583)    (0.1819)
# nodaded                         0.0166     -0.0166      0.0345
#                               (0.0507)   (-0.0507)    (0.4342)
# nomomed                        -0.3466      0.3466      0.0974
#                              (-1.6336)    (1.6336)    (1.9268)
# daded                           0.1543     -0.1543     -0.0334
#                               (5.4141)   (-5.4141)   (-4.8430)
# momed                           0.1737     -0.1737     -0.0415
#                               (6.0967)   (-6.0967)   (-6.3295)
# famed1                          1.3853     -1.3853     -0.1157
#                               (2.8115)   (-2.8115)   (-0.9723)
# famed2                          1.5971     -1.5971     -0.1984
#                               (3.6346)   (-3.6346)   (-1.8783)
# famed3                          0.9586     -0.9586     -0.1087
#                               (2.3741)   (-2.3741)   (-1.1202)
# famed4                          0.8007     -0.8007     -0.1439
#                               (2.9292)   (-2.9292)   (-2.3636)
# famed5                          0.7501     -0.7501     -0.1305
#                               (1.9056)   (-1.9056)   (-1.3922)
# famed6                          0.7293     -0.7293     -0.1116
#                               (1.9062)   (-1.9062)   (-1.2163)
# famed7                          0.5643     -0.5643     -0.0981
#                               (1.4324)   (-1.4324)   (-1.0779)
# famed8                          0.7752     -0.7752     -0.1523
#                               (2.1832)   (-2.1832)   (-1.7526)
# col4                            0.3582     -0.3582     -0.0739
#                               (3.5220)   (-3.5220)   (-3.3000)
# age76                           0.8591      0.1409     -0.5162
#                               (3.1799)    (0.5217)   (-8.3963)
# agesq76                        -0.0146      0.0146      0.0123
#                              (-3.0943)    (3.0943)    (11.284)
# --------------------------------------------------------------
#
# T-stats reported in parentheses
# T-stats use same covariance type as original model
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept     -0.3858     0.3703    -1.0417     0.2976     -1.1116      0.3401
# black         -0.1678     0.0294    -5.7108     0.0000     -0.2254     -0.1102
# south76       -0.1392     0.0289    -4.8158     0.0000     -0.1958     -0.0825
# smsa76         0.0920     0.0441     2.0887     0.0367      0.0057      0.1784
# reg2           0.0757     0.0431     1.7570     0.0789     -0.0087      0.1602
# reg3           0.1237     0.0417     2.9619     0.0031      0.0418      0.2055
# reg4           0.0259     0.0531     0.4881     0.6255     -0.0782      0.1300
# reg5           0.1242     0.0456     2.7241     0.0064      0.0348      0.2135
# reg6           0.1349     0.0479     2.8130     0.0049      0.0409      0.2288
# reg7           0.1052     0.0510     2.0608     0.0393      0.0051      0.2052
# reg8          -0.0857     0.0613    -1.3985     0.1620     -0.2058      0.0344
# reg9           0.0906     0.0497     1.8224     0.0684     -0.0068      0.1881
# smsa66         0.0379     0.0229     1.6549     0.0979     -0.0070      0.0828
# sinmom14      -0.0041     0.0325    -0.1273     0.8987     -0.0679      0.0597
# nodaded       -0.0523     0.0549    -0.9523     0.3410     -0.1598      0.0553
# nomomed        0.0126     0.0378     0.3331     0.7390     -0.0615      0.0867
# daded         -0.0108     0.0089    -1.2187     0.2229     -0.0283      0.0066
# momed         -0.0017     0.0092    -0.1844     0.8537     -0.0197      0.0164
# famed1        -0.2041     0.1186    -1.7216     0.0851     -0.4365      0.0283
# famed2        -0.1484     0.1158    -1.2815     0.2000     -0.3754      0.0786
# famed3        -0.1298     0.0880    -1.4754     0.1401     -0.3023      0.0426
# famed4        -0.0690     0.0604    -1.1437     0.2528     -0.1873      0.0493
# famed5        -0.0656     0.0772    -0.8498     0.3954     -0.2170      0.0857
# famed6        -0.1111     0.0749    -1.4843     0.1377     -0.2579      0.0356
# famed7        -0.0867     0.0739    -1.1729     0.2408     -0.2314      0.0581
# famed8        -0.1132     0.0696    -1.6271     0.1037     -0.2495      0.0231
# grade76        0.1312     0.0490     2.6763     0.0074      0.0351      0.2272
# exp76          0.0638     0.0242     2.6396     0.0083      0.0164      0.1113
# expsq76       -0.1277     0.1177    -1.0847     0.2781     -0.3583      0.1030
# ==============================================================================
#
# Endogenous: grade76, exp76, expsq76
# Instruments: col4, age76, agesq76
# Robust Covariance (Heteroskedastic)
# Debiased: False

# %%
data.loc[:,['grade76','exp76','expsq76','col4','age76','agesq76']].corr()
# Out:
#           grade76     exp76   expsq76      col4     age76   agesq76
# grade76  1.000000 -0.652956 -0.631521  0.144240 -0.008740 -0.011597
# exp76   -0.652956  1.000000  0.967202 -0.061621  0.763074  0.764028
# expsq76 -0.631521  0.967202  1.000000 -0.064001  0.738063  0.743718
# col4     0.144240 -0.061621 -0.064001  1.000000  0.041730  0.042734
# age76   -0.008740  0.763074  0.738063  0.041730  1.000000  0.998822
# agesq76 -0.011597  0.764028  0.743718  0.042734  0.998822  1.000000

# %%
res.first_stage.diagnostics
# Out:
#          rsquared  partial.rsquared  shea.rsquared       f.stat    f.pval  \
# grade76  0.295270          0.008105       0.006185    26.010332  0.000009
# exp76    0.705598          0.641137       0.085975  5318.851936  0.000000
# expsq76  0.675432          0.609415       0.082337  3562.538602  0.000000
#
#           f.dist
# grade76  chi2(3)
# exp76    chi2(3)
# expsq76  chi2(3)

# %% [markdown]
# ### Exercise 7

# %%
formula='wage76 ~ 1 + black+south76+smsa76+reg2+reg3+reg4+reg5+reg6+reg7+reg8+reg9+smsa66+sinmom14+nodaded+nomomed+daded+momed+famed1+famed2+famed3+famed4+famed5+famed6+famed7+famed8+exp76+expsq76 + [grade76 ~ col4]'
res = IV2SLS.from_formula(formula, data).fit(cov_type='robust')
res.first_stage.diagnostics
# Out:
#          rsquared  partial.rsquared  shea.rsquared    f.stat  f.pval   f.dist
# grade76  0.528641          0.004701       0.004701  15.14017  0.0001  chi2(1)

# %% [markdown]
# ### Exercise 8

# %%
from scipy.stats import norm, multivariate_normal

N=10000
π=1
β=2
uv=multivariate_normal([0,0],[[1,0.5],[0.5,1]]).rvs(N)
u=uv[:,0]
v=uv[:,1]
z=norm().rvs(N)
y2=π*z+v
y1=β*y2**2+u
data=pd.DataFrame({'y1':y1,'y2':y2,'z':z,'u':u,'v':v})

# %%
res = IV2SLS.from_formula('y1~[I(y2**2)~z]', data).fit(cov_type='unadjusted')
print(res.first_stage)
print('\n'.join(res.summary.as_text().split('\n')[8:]))
# Out:
#     First Stage Estimation Results
# =====================================
#                            I(y2 ** 2)
# -------------------------------------
# R-squared                      0.0010
# Partial R-squared              0.0010
# Shea's R-squared               0.0010
# Partial F-statistic            10.370
# P-value (Partial F-stat)       0.0013
# Partial F-stat Distn          chi2(1)
# ========================== ==========
# z                              0.1117
#                              (3.2202)
# -------------------------------------
#
# T-stats reported in parentheses
# T-stats use same covariance type as original model
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# I(y2 ** 2)     2.0059     0.0891     22.512     0.0000      1.8312      2.1805
# ==============================================================================
#
# Endogenous: I(y2 ** 2)
# Instruments: z
# Unadjusted Covariance (Homoskedastic)
# Debiased: False

# %%
first_stage=smf.ols('I(y2**2)~0+z',data).fit()
data.loc[:,'y2sqfit']=first_stage.fittedvalues
second_stage=smf.ols('y1~0+y2sqfit',data).fit()
print(first_stage.summary().tables[1])
print(second_stage.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# z              0.1117      0.035      3.220      0.001       0.044       0.180
# ==============================================================================
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# y2sqfit        2.0059      0.627      3.198      0.001       0.776       3.236
# ==============================================================================

# %%
first_stage=smf.ols('y2~0+z',data).fit()
data.loc[:,'y2fit']=first_stage.fittedvalues
second_stage=smf.ols('y1~0+I(y2fit**2)',data).fit()
print(first_stage.summary().tables[1])
print(second_stage.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# z              0.9953      0.010     98.589      0.000       0.975       1.015
# ==============================================================================
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# I(y2fit ** 2)     2.6844      0.031     86.285      0.000       2.623       2.745
# =================================================================================
